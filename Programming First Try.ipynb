# %% [markdown]
# # Hallo!
# Wir helfen dir dabei, dein Ansteckungsrisiko durch COVID-19 zu berechnen.

# %% [markdown]
# Zuerst brauchen wir ein paar Daten von dir:

# %%
print("Wann hattest du das letzte Mal Kontakt zu Personen außerhalb deines Haushalts?")
# Out:
# Wann hattest du das letzte Mal Kontakt zu Personen außerhalb deines Haushalts?

# %% [markdown]
# # Hallo!

# %% [markdown]
# Herzlich Willkommen. Ich bin das allwissende Orakel, dass dir hilft heute eine Entscheidung zu treffen.

# %%
from time import sleep
Name = input("Wie ist dein Name?:")
sleep (1)
print("Hallo",Name,"! Schön dich kennen zu lernen!")
sleep (2)
print ("Welche Frage liegt dir auf dem Herzen?")
sleep (2)
Frage = input ("Deine Frage:")
Frage = Frage
print ("Das ist eine gute Frage..")
sleep (3)
print ("Lass mich mal überlegen.")
sleep (3)
print ("Um dir eine genaue Antwort geben zu können, muss ich noch dein Alter wissen.")
sleep(1)
Alter = input ("Dein Alter:")
print ("Du bist also", Alter, "Jahre alt.")
sleep (3)
print ("Interessant..")
if int(Alter)<15:
    sleep(2)
    print("Du bist ja ganz schön jung. Vielleicht fragst du lieber deine Eltern nach einem Ratschlag.")
sleep (3)
print("Langsam komme ich der Antwort näher.")
print("Aber um mir sicher zu sein, brauche ich noch dein Sternzeichen.")
sleep(2)
Sternzeichen = input("Dein Sternzeichen:")
print("Aaah, du gehörst also zum Sternzeichen",Sternzeichen,". Das erklärt schonmal einiges.")
# Out:
# Wie ist dein Name?:Dinah
# Hallo Dinah ! Schön dich kennen zu lernen!
# Welche Frage liegt dir auf dem Herzen?
# Deine Frage:Bin ich dumm?
# Das ist eine gute Frage..
# Lass mich mal überlegen.
# Um dir eine genaue Antwort geben zu können, muss ich noch dein Alter wissen.
# Dein Alter:27
# Du bist also 27 Jahre alt.
# Interessant..
# Langsam komme ich der Antwort näher.
# Aber um mir sicher zu sein, brauche ich noch dein Sternzeichen.
# Dein Sternzeichen:Fische
# Aaah, du gehörst also zum Sternzeichen Fische . Das erklärt schonmal einiges.
